# %% [markdown]
# # Récupérer des données
#
# Pandas offre la possibilité d'importer des données de nombreuses origines :
#
# * CSV
# * Excel
# * tables extraite de pages web
# * base de donnée SQL
# * format spécifique de fichier ou d'application (HDF, JSON, Parquet...)
#
# Les deux derniers points ne sont pas présentés ici ainsi que d'autres qu'on retrouvera dans la [liste de E/S](https://pandas.pydata.org/pandas-docs/stable/api.html#input-output).
#
# Il existe aussi des bibliothèques tierces qui permettent de récupérer des données au format de Pandas.
#
# En pratique il est rare qu'il faille faire un travail important pour intégrer des données dans un tableau de Pandas.

# %% [markdown]
# ## CSV
#
# Il s'agit d'un format simple que l'humain peut lire. Il peut être généré par un logiciel de bureautique ou des programmes
# spécialisés. Certains paramêtres pouvant varier d'un fichier à un autre, Pandas offre la possibilité de les préciser en
# argument.
#
# Regardons un fichier CSV :

# %%
# !cat data/data1.csv  # a unix command (starts with !)
# Out:
# product; price; amount; date_in
#   'pen';   0.2;  10000; 2016-03-23
#  'ball';   2.1;   2300; 2016-05-12
# 'board';  1.75;  10000; 2016-05-03

# %% [markdown]
# Pour intégrer ce fichier dans un tableau nous allons spécifier les paramètre nécessaires :
#
# * ici le séparateur entre les champs est `;` alors que la valeur par défaut est `,` aussi on indique `sep=';'`
# * certaines lignes commencent pas des espaces qu'il faut retirer, donc `skipinitialspace=True`
# * les quotes autour des mots doivent être retirées, on lui indique qu'il s'agit de simples quotes
# * on précise qu'il y a un colonne de date afin que Pandas les convertisse en date plutôt que de les lire comme des
#   chaînes de caractères, `parse_dates=[3]`
#
# La documentation de [read_csv](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) liste tous
# les paramètres.

# %%
import pandas as pd

data = pd.read_csv("data/data1.csv", sep=';', skipinitialspace=True, quotechar="'",
                   parse_dates=[3])
data
# Out:
#   product  price  amount    date_in
# 0     pen   0.20   10000 2016-03-23
# 1    ball   2.10    2300 2016-05-12
# 2   board   1.75   10000 2016-05-03

# %%
type(data['date_in'].values[1])
# Out:
# numpy.datetime64

# %% [markdown]
# ## Excel
#
# Le format d'Excel, `xls` ou `xlsx`, est lu par Pandas. Voici la liste des musées francais stockée sur le site
# des données ouvertes de l'État
# [data.gouv.fr](https://www.data.gouv.fr).

# %%
url = "https://www.data.gouv.fr/s/resources/liste-et-localisation-des-musees-de-france/20160404-110647/Liste_musees_de_France.xls"
data = pd.read_excel(url)
data
# Out:
#                      NOMREG                    NOMDEP DATEAPPELLATION FERME  \
# 0                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 1                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 2                    ALSACE                  BAS-RHIN      01/02/2003   OUI
# 3                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 4                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 5                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 6                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 7                    ALSACE                  BAS-RHIN      15/12/2002   NON
# 8                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 9                    ALSACE                  BAS-RHIN      01/02/2003   NON
# 10                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 11                   ALSACE                  BAS-RHIN      23/06/2008   NON
# 12                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 13                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 14                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 15                   ALSACE                  BAS-RHIN      06/01/2002   NON
# 16                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 17                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 18                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 19                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 20                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 21                   ALSACE                  BAS-RHIN      26/03/2007   NON
# 22                   ALSACE                  BAS-RHIN      01/02/2003   OUI
# 23                   ALSACE                  BAS-RHIN      01/02/2003   NON
# 24                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# 25                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# 26                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# 27                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# 28                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# 29                   ALSACE                 HAUT-RHIN      01/02/2003   NON
# ...                     ...                       ...             ...   ...
# 1214            RHÔNE-ALPES                     LOIRE      01/02/2003   NON
# 1215            RHÔNE-ALPES                     RHÔNE      09/07/2005   NON
# 1216            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1217            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1218            RHÔNE-ALPES                     RHÔNE      19/07/2005   NON
# 1219            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1220            RHÔNE-ALPES                     RHÔNE      21/03/2011   OUI
# 1221            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1222            RHÔNE-ALPES                     RHÔNE      01/02/2003   OUI
# 1223            RHÔNE-ALPES                     RHÔNE      01/02/2003   OUI
# 1224            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1225            RHÔNE-ALPES                     RHÔNE      06/01/2002   NON
# 1226            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1227            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1228            RHÔNE-ALPES                     RHÔNE      19/07/2005   NON
# 1229            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1230            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1231            RHÔNE-ALPES                     RHÔNE      09/07/2005   OUI
# 1232            RHÔNE-ALPES                     RHÔNE      01/02/2003   NON
# 1233            RHÔNE-ALPES                    SAVOIE      01/02/2003   NON
# 1234            RHÔNE-ALPES                    SAVOIE      01/02/2003   OUI
# 1235            RHÔNE-ALPES                    SAVOIE      01/02/2003   NON
# 1236            RHÔNE-ALPES                    SAVOIE      01/02/2003   NON
# 1237            RHÔNE-ALPES                    SAVOIE      01/02/2003   OUI
# 1238            RHÔNE-ALPES                    SAVOIE      06/01/2002   OUI
# 1239            RHÔNE-ALPES                    SAVOIE      06/01/2002   NON
# 1240            RHÔNE-ALPES                    SAVOIE      06/01/2002   NON
# 1241            RHÔNE-ALPES                    SAVOIE      01/02/2003   OUI
# 1242            RHÔNE-ALPES                    SAVOIE      01/02/2003   NON
# 1243  ST PIERRE ET MIQUELON  SAINT-PIERRE ET MIQUELON      01/02/2003   NON
#
#                ANNREOUV ANNEXE  \
# 0                   NaN    NaN
# 1                   NaN    NaN
# 2          29 juin 2013    NaN
# 3                   NaN    NaN
# 4                   NaN    NaN
# 5                   NaN    NaN
# 6                   NaN    NaN
# 7                   NaN    NaN
# 8                   NaN    NaN
# 9                   NaN    NaN
# 10                  NaN    NaN
# 11                  NaN    NaN
# 12                  NaN    NaN
# 13         29 Juin 2007    NaN
# 14                  NaN    NaN
# 15                  NaN    NaN
# 16                  NaN    NaN
# 17                  NaN    NaN
# 18                  NaN    NaN
# 19                  NaN    NaN
# 20                  NaN    NaN
# 21       1 juillet 2011    NaN
# 22                 2013    NaN
# 23                  NaN    NaN
# 24                  NaN    NaN
# 25                  NaN    NaN
# 26    15 septembre 2007    NaN
# 27                  NaN    NaN
# 28                  NaN    NaN
# 29                  NaN    NaN
# ...                 ...    ...
# 1214                NaN    NaN
# 1215                NaN    NaN
# 1216                NaN    NaN
# 1217                NaN    NaN
# 1218                NaN    NaN
# 1219                NaN    NaN
# 1220               2014    NaN
# 1221                NaN    NaN
# 1222         Pas d'info    NaN
# 1223               2014    NaN
# 1224                NaN    NaN
# 1225                NaN    NaN
# 1226                NaN    NaN
# 1227       12 juin 2009    NaN
# 1228                NaN    NaN
# 1229                NaN    NaN
# 1230                NaN    NaN
# 1231            Inconnu    NaN
# 1232          Juin 2001    NaN
# 1233                NaN    NaN
# 1234         Non prévue    NaN
# 1235                NaN    NaN
# 1236                  ?    NaN
# 1237           Inconnue    NaN
# 1238          2011/2012    NaN
# 1239                NaN    NaN
# 1240                NaN    NaN
# 1241        Pas d'infos    NaN
# 1242                NaN    NaN
# 1243                NaN    NaN
#
#                                            NOM DU MUSEE  \
# 0                               Musée de la Folie Marco
# 1                                   Musée de la Poterie
# 2               Musée de Bouxwiller et du Pays de Hanau
# 3                                        Musée Alsacien
# 4                                      Musée Historique
# 5                                Musée de la Chartreuse
# 6            Maison de l'Archéologie des Vosges du Nord
# 7           Musée de l'Image Populaire de Pfaffenhoffen
# 8                                          Musée du Fer
# 9                            Musée du Château des Rohan
# 10                            Musée des Arts Décoratifs
# 11                                   Musée Tomi Ungerer
# 12                                 Musée des Beaux-Arts
# 13                                     Musée Historique
# 14                                       Musée Alsacien
# 15                                  Musée Archéologique
# 16                          Musée de l'Œuvre Notre-Dame
# 17                  Cabinet des Estampes et des Dessins
# 18    Musée d'Art Moderne et Contemporain de Strasbourg
# 19    Musée Zoologique de l'Université Louis Pasteur...
# 20                                   Musée J.F. Oberlin
# 21                                        Musée Lalique
# 22                                     Musée Westercamp
# 23                  Musée de la Bataille du 6 Août 1870
# 24                         Musée Sundgauvien d'Altkirch
# 25                                   Musée Gallo-Romain
# 26                           Musée de la Porte de Thann
# 27                                  Musée d'Unterlinden
# 28                                      Musée Bartholdi
# 29    Musée d'Histoire Naturelle et d'Ethnographie d...
# ...                                                 ...
# 1214                                        Musée Rural
# 1215                        Musée Barthélemy-Thimonnier
# 1216  Musée Folklorique et Traditions Populaires Mar...
# 1217                   Musée d'Art Contemporain de Lyon
# 1216  Ouvert du mardi au dimanche en mars/avril, oct...
# 1217  Ouvert du mercredi au dimanche de 11h à 18h, l...
# 1218  Ouvert du lundi au vendredi de 9h à 12h et de ...
# 1219  Ouvert du mercredi à vendredi de 9h à 17h30, s...
# 1220  Espace d'information ouvert du mardi au samedi...
# 1221         Ouvert du mardi au dimanche de 10 h à 18 h
# 1222                                 Fermé pour travaux
# 1223  Ouvert du mercredi au samedi de 13h à 18h, dim...
# 1224         Ouvert du mardi au dimanche de 10h à 17h30
# 1225  Ouvert du mercredi au lundi de 10h à 18h, vend...
# 1226  Ouvert  du mardi au dimanche de 10h à 12h et d...
# 1227      Ouvert du mercredi au dimanche de 11h à 18h30
# 1228  Ouvert du mercredi au dimanche de 9h30 à 12h e...
# 1229  Ouvert du mardi au dimanche et les lundis féri...
# 1230  Ouvert du mardi au dimanche de 10h à 18h et de...
# 1231  Ouvert durant les travaux uniquement lors des ...
# 1232  Ouvert le mercredi de 13h30 à 18h, jeudi et ve...
# 1233  Ouvert du lundi au samedi en juillet-août de 1...
# 1234                                                NaN
# 1235  Ouvert du mercredi au lundi de 10h à 12h et de...
# 1236  Ouvert du 1er juin au 30 septembre tous les jo...
# 1237                                                NaN
# 1238  Fermé en 2009. Ouvert du mercredi au lundi de ...
# 1239  Ouvert du mercredi au lundi de 10h à 12h et de...
# 1240  Ouvert du mercredi au lundi de 10h à 12h et de...
# 1241  Ouvert du mardi au vendredi, lematin sur rdv p...
# 1242  Ouvert du lundi au samedi de 9h à 12h et de 14...
# 1243  Ouvert samedi et dimanche de 10h à 12h et de 1...
#
#                                         JOURS NOCTURNES
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1214                                                NaN
# 1215                                                NaN
# 1216                                                NaN
# 1217                                                NaN
# 1218                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1221                                                NaN
# 1222                                                NaN
# 1223                                                NaN
# 1224                                                NaN
# 1225         1er vendredi de chaque mois de 10h30 à 22h
# 1226                                                NaN
# 1227                                                NaN
# 1228                                                NaN
# 1229                                                NaN
# 1230                                                  ç
# 1231                                                NaN
# 1232                                                NaN
# 1233                                                NaN
# 1234                                                NaN
# 1235                                                NaN
# 1236                                                NaN
# 1237                                                NaN
# 1238                                                NaN
# 1239                                                NaN
# 1240                                                NaN
# 1241                                    Nuit des musées
# 1242                                                NaN
# 1243  Nuit Blanche (octobre) jusqu'à minuit et de mi...
#
# [1244 rows x 14 columns]

# %% [markdown]
# ## read_html
#
# Avec de la chance (et parfois à l'aide bibliothèque [BeautifullSoup](https://www.crummy.com/software/BeautifulSoup/)),
# Pandas peut lire un tableau dans une page web.
# morceaux pour pouvoir le lire.
#
# Voici un exemple à partir d'une page du [FDIC](https://www.fdic.gov/) (il faut descendre la page web pour voir le tableau).

# %%
import IPython
url = 'http://www.fdic.gov/bank/individual/failed/banklist.html'
iframe = '<iframe src=' + url + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=http://www.fdic.gov/bank/individual/failed/banklist.html width=700 height=350></iframe>

# %%
dfs = pd.read_html(url)    # returns a list of dataframes, one for each table in the web page

# %%
display(dfs[0].head(), dfs[0].tail())
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   December 5, 2017
#                              Bank Name        City  ST   CERT  \
# 550                 Superior Bank, FSB    Hinsdale  IL  32646
# 551                Malta National Bank       Malta  OH   6629
# 552    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 553  National State Bank of Metropolis  Metropolis  IL   3815
# 554                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date       Updated Date
# 550                Superior Federal, FSB      July 27, 2001    August 19, 2014
# 551                    North Valley Bank        May 3, 2001  November 18, 2002
# 552  Southern New Hampshire Bank & Trust   February 2, 2001  February 18, 2003
# 553              Banterra Bank of Marion  December 14, 2000     March 17, 2005
# 554                   Bank of the Orient   October 13, 2000     March 17, 2005

# %% [markdown]
# On note que Pandas a lu les 555 lignes du tableau alors que la page web n'en montre que 25 ! Cela est du
# au fait que l'affichage de la page ne montre qu'une partie du code source qui lui contient les 255 lignes.

# %% [markdown]
# ## Pandas datareader
#
# La bibliothèque [pandas-datereader](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) permet
# de récupérer facilement des données sur le web. Malheureusement certains sites sources changent trop
# souvent leur format
# ou ne sont pas toujours fiables ce qui pose des problèmes de maintenance à cette bibliothèque. Aussi Yahoo! Finance
# et Google Finance ont été abandonnés.
#
# Les bases accessibles via pandas datareader sont pour la version 0.6.0 :
#
# * Morningstar
# * IEX
# * Robinhood
# * Enigma
# * Quandl
# * St.Louis FED (FRED)
# * Kenneth French's data library
# * World Bank
# * OECD
# * Eurostat
# * Thrift Savings Plan
# * Nasdaq Trader symbol definitions
# * Stooq
# * MOEX
#
# Attention certaines bases demandent d'avoir une autorisation d'accès laquelle s'obtient sur leur site web.

# %%
import pandas_datareader.data as web
import datetime as dt

start = dt.datetime(2018, 8, 1)
end = dt.datetime(2018, 8, 10)
df = web.DataReader('AAPL', 'iex', start, end)  # Apple stock prices thanks to IEX
df
# Out:
#                 open      high       low     close    volume
# date
# 2018-08-01  197.7441  200.3558  195.9368  200.0976  67935716
# 2018-08-02  199.1840  206.9297  198.9556  205.9466  62404012
# 2018-08-03  205.5891  207.2872  204.0502  206.5424  33447396
# 2018-08-06  206.5524  207.7937  205.6288  207.6149  25425387
# 2018-08-07  207.8632  208.0419  205.3210  205.6685  25587387
# 2018-08-08  204.6159  206.3637  203.0966  205.8076  22525487
# 2018-08-09  205.8374  208.3200  205.7579  207.4262  23492626
# 2018-08-10  206.6390  208.3730  205.9514  206.8084  24611202

# %% [markdown]
# {{ PreviousNext("pd08 -- Tools.ipynb", "../lesson7 Graphics/10 -- Static graphics with Matplotlib.ipynb")}}
